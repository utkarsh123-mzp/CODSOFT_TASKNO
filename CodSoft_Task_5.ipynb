# %%
# !pip install requests beautifulsoup4 pandas
# Out:
# Requirement already satisfied: requests in c:\users\pandi\anaconda3\lib\site-packages (2.32.5)
# Requirement already satisfied: beautifulsoup4 in c:\users\pandi\anaconda3\lib\site-packages (4.13.5)
# Requirement already satisfied: pandas in c:\users\pandi\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\pandi\anaconda3\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pandi\anaconda3\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pandi\anaconda3\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pandi\anaconda3\lib\site-packages (from requests) (2026.1.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\pandi\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\pandi\anaconda3\lib\site-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\pandi\anaconda3\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pandi\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pandi\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pandi\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\pandi\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# # Author: Utkarsh Upadhyay
# # Task 5: Web Data Extraction

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# 1. Setting URL
url = "https://books.toscrape.com/"

# 2. Fetching HTML Page
print("Fetching website data...")
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# 3. Search HTML Block
articles = soup.find_all('article', class_='product_pod')
books_data = []

print("Extracting book details...")

for article in articles:
    title = article.h3.a['title']
    
    price_text = article.find('p', class_='price_color').text
    price = float(price_text.replace('Â', '').replace('£', '').strip())
    
    rating = article.p['class'][1]
    
    books_data.append({'Title': title, 'Price (£)': price, 'Rating': rating})


df_books = pd.DataFrame(books_data)

df_books.to_csv('scraped_books.csv', index=False)

print("\n--- Scraping Successful! ---")
print("First 5 scraped books:")
print(df_books.head())
# Out:
# Fetching website data...
# Extracting book details...
#
# --- Scraping Successful! ---
# First 5 scraped books:
#                                    Title  Price (£) Rating
# 0                   A Light in the Attic      51.77  Three
# 1                     Tipping the Velvet      53.74    One
# 2                             Soumission      50.10    One
# 3                          Sharp Objects      47.82   Four
# 4  Sapiens: A Brief History of Humankind      54.23   Five
